# %% [markdown]
# La classe `File`, les procédures `afficher`, `attendre` et la fonction `saisie_joueur` sont données.

# %%
from IPython.display import clear_output
from time import sleep
from random import randint

class File:
    def __init__(self):
        self.liste = []
        
    def est_vide(self):
        return self.liste == []
    
    def enfiler(self, elem):
        self.liste.append(elem)
    
    def defiler(self):
        return self.liste.pop(0)

def afficher(couleur):
    clear_output()
    W = chr(0x26aa)
    DICO = {"bleu": chr(0x1f535) + W*3,
            "rouge": W + chr(0x1f534) + W*2,
            "jaune": W*2 + chr(0x1f7e1) + W,
            "vert": W*3 + chr(0x1f7e2)}
    print(DICO[couleur])

def attendre(temps):
    sleep(temps)
    
def saisie_joueur():
    clear_output()
    COULEURS = ["bleu", "rouge", "jaune", "vert"]
    saisie = 0
    while not saisie in range(1, 5):
        saisie = int(input(f"{chr(0x1f535)}(1)  {chr(0x1f534)}(2)  {chr(0x1f7e1)}(3)  {chr(0x1f7e2)}(4) - Couleur choisie (1, 2, 3 ou 4): "))
    return COULEURS[saisie-1]

# %% [markdown]
# **Question 3**

# %%
def ajout_couleur(sequence):
    """
    Ajoute une couleur aléatoire dans une file.
    - Entrée : sequence (instance de la classe File)
    - Sortie : sequence (instance de la classe File)
    """
    COULEURS = ["bleu", "rouge", "jaune", "vert"]
    indice = randint(..., ...)
    ...
    return sequence

# %% [markdown]
# **Question 4**

# %% [markdown]
# **Question 5**

# %%
def afficher_sequence(sequence):
    """
    Ajoute une nouvelle couleur dans une file puis affiche
    successivement les couleurs présentes dans cette file.
    - Entrée : sequence (instance de la classe File)
    Effet : allumages successifs de boutons du jeu
    """
    ajout_couleur(sequence)
    stock = File()
    while ...:  # on vide la file sequence dans la file stock
        couleur = ...
        afficher(...)
        attendre(...)  # pause d’une demi seconde
        ...
    while ...:  # on vide la file stock dans la file sequence
        ...

# %% [markdown]
# **Question 6**

# %%
def tour_de_jeu(sequence):
    ...
    stock = File()
    while ...:
        coul_joueur = ...
        coul_sequence = ...
        if ...:
            ...
        else:
            ...
            ...
    while ...:
        ...

# %% [markdown]
# **Test du jeu**

# %%
sequence = File()
for _ in range(5):
    tour_de_jeu(sequence)

# %%
if len(sequence.liste) == 5:
    print("Gagné !")
else:
    print("Perdu !")
